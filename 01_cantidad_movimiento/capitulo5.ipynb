# %% [markdown]
# <h1 style="text-align:center;">Capítulo 05 - Equipos y aplicaciones.</h1>
# <p style="text-align:center;">En esta unidad se estudian las principales máquinas impulsoras utilizadas en la industria para el transporte de líquidos y gases. Se analizan los criterios de selección, operación y desempeño de bombas, ventiladores, soplantes y compresores, considerando sus curvas características y condiciones de funcionamiento. Asimismo, se abordan conceptos fundamentales como el acoplamiento entre equipos y sistemas de tuberías, el uso de variadores de velocidad, el cálculo del NPSH y los principios de semejanza y escalado, proporcionando herramientas para el diseño y la selección adecuada de estos equipos en aplicaciones industriales.<p>

# %% [markdown]
# Los seis mecanismos más usuales para dar impulso al fluido por la lı́nea de conducción son:
# 1. Fuerza de gravedad.
# 2. Fuerza centrı́fuga.
# 3. Impulso mecánico combinado.
# 4. Desplazamiento positivo (volumétrico).
# 5. Transferencia de Cantidad de Movimiento (m × v).
# 6. Fuerzas electromagnéticas.
#
# clasificación de las máquinas impulsoras por la presión a la que pueden entregar el fluido
# que pasa por ellas,
#
# 1. Bombas, que entregan presiones de salida desde 0 hasta miles de psig.
# 2. Ventiladores, que brindan presiones de salida menores a 1.0 psi = 28 in columna agua.
# 3. Soplantes, que permiten obtener presiones de salida desde 1 hasta 44 psig.
# 4. Compresores, que logran entregar presiones de salida superiores a 44 psig.
#
# Esto permite ver que las máquinas impulsoras son en realidad tres grandes familias:
# - bombas para fluidos incompresibles
# - ventiladores y soplantes para fluidos compresibles a presiones bajas o moderadas
# - compresores para fluidos compresibles a presiones altas
